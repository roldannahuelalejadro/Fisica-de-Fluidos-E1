# %% [markdown]
# # **INTEGRANTES**
# **Completar con el nombre y la libreta universitaria de cada integrante**
#
# **INTEGRANTE Nº1:**
#
# **INTEGRANTE Nº2:**

# %% [markdown]
# #**Ondas de gravedad entre 2 fluidos**
#
# En esta guía usaremos gran parte de lo aprendido en el curso para atacar un problema puntual: ondas de gravedad en la interfaz de dos fluidos incompresibles, ideales e inmiscibles (por ejemplo, agua y aceite).
# Considere dos columnas de fluido de densidades $\rho_1$ y $\rho_2>\rho_1$ y alturas $h_1$ y $h_2$ delimitados por tapas horizontales cómo muestra la figura.
# Ambos fluidos son incompresibles y existe gravedad $g$.
#
# Aunque esta guía esté separada por ejercicios, su resolución es bastante secuencial. Primero hay una parte analítica con dos ejercicios que debe ser resuelta antes de pasar a los 3 ejercicios numéricos, cuyo objetivo es principalmente ayudar a entender los resultados analíticos.
#
# ![](https://drive.google.com/uc?export=view&id=1covyfLlZoCTl3nrySK-sfb12ial3xsgP)

# %% [markdown]
# ## **Parte analítica**

# %% [markdown]
# ### **Ejercicio 1: Estudio del problema lineal**
#
# (a) Planteando potenciales $\phi_1$ y $\phi_2$ en cada región, determine las 4 condiciones de contorno para una perturbación armónica con vector de onda horizontal $k$.
#
# (b) Para el problema linealizado, proponga soluciones oscilatorias y obtenga la relación de dispersión $\omega_k$ para perturbaciones respecto al equilibrio estático ($\mathbf{v}_1=0=\mathbf{v}_2$). Verifique que recupera casos conocidos en los límites apropiados. ¿Qué ocurre si $\rho_2<\rho_1$?
#
# (c) En el límite de fluido superior no acotado ($kh_1 \to \infty$) y aguas poco produndas ($kh_2 \ll 1$), expanda la relación de dispersión al orden más bajo _no lineal_ en $kh_2$. _Ayuda: Esta expansión resultará de orden 2._
#
# (d) Explique porque no es posible tener una interacción de 3 ondas resonante para el $\omega_k$ hallado. _Recuerde que una interacción de 3 ondas resonante requiere $k_1 = k_2 + k_3$ junto con $\omega_1 = \omega_2 + \omega_3$ con $k_1\neq k_2, k_3$ simultáneamente_.

# %% [markdown]
# **SUS CUENTAS AQUI**

# %% [markdown]
# (a):
# considerando un problema bidimensional (con eje vertical $z$ y eje horizontal $x$), planteamos un potencial $\phi$ tal que $\nabla \phi = v$, y llamamos $\chi$ a la perturbación alrededor del cero. Teniendo esto en cuenta, pedimos que la velocidad en las tapas sea cero, y que tanto las presiones como las velocidades sean iguales en la perturbación, es decir
#
# $$
# \partial_z \phi_1|_{z=h_1} = 0 = \partial_z \phi_2|_{z=-h_2}
# $$
# $$$$
# $$P_1|_{z=\chi} = P_2|_{z=\chi} = P$$
# $$$$
# $$
# \partial_z \phi_1|_{z=\chi} = \partial_z \phi_2|_{z=\chi}
# $$
#
# Además, para que los fluidos vayan como la perturbación, pedimos en $ z = 0 $ que $ \partial_t \chi = \partial_z \phi \quad$.

# %% [markdown]
# (b)
# **Caso $v_1 =v_2 = 0 $**
#
# Los potenciales de cada fluido deben cumplir la ecuación de Laplace $ \nabla^2 \phi =0 $. Si proponemos una solución oscilatoria de la forma $\phi(x, z, t) = A(z)e ^{i(kx -wt)} $ y reemplazamos $\phi$ en la ecuación de Laplace, obtenemos
#
# $$
# \partial_z ^2A(z) - k^2A(z) = 0
# $$
#
# Lo cual es la ecuación diferencial del antioscilador, por lo que puedo proponer como solución un coseno hiperbólico, con una fase y amplitud a determinar, por lo que para cada potencial tendríamos, a priori, una función de la forma
#
# $$
# \phi_{1, 2} (x, z, t) = C_{1, 2} cosh(k(z + \theta_{1, 2}))e^{i(kx-wt)}
# $$
#
# Al imponer las condiciones de borde en las tapas obtenemos $ \theta_1 = -h_1 $ y $ \theta_2 = h_2 $
#
# Por otro lado, planteamos a la perturbación oscilatoria como
#
# $$
# \chi (x, t) = \chi_0 e^{i(kx - wt)}
# $$
#
# Al imponer la condición $ \quad \partial_t \chi = \partial_z \phi \quad $ en $ \quad z =0 \quad $ obtenemos la ecuación
#
# $$
# C_1 k . sinh(-kh_1)e^{i(kx - wt)} = -iw \chi_0 e^{i(kx - wt)}
# $$
#
# Por lo que, despejando, obtenemos
#
# $$
# C_1 = \frac{iw\chi_0}{k.sinh(k.h_1)}
# $$
#
# Similarmente, $C_2$ es de la forma
#
# $$
# C_2 = -\frac{iw\chi_0}{k.sinh(k.h_2)}
# $$
#
# Por otra parte, de la ecuación de Bernoulli obtenemos
#
# $$
# -\frac{P}{\rho} + gz = \partial_t \phi
# $$
#
# Despejando,
#
# $$
# P = \rho gz - \rho \partial_t \phi
# $$
#
# Como en $z = \chi$ sabemos que $P_1 = P_2$, si igualamos las expresiones de Bernoulli llegamos a la relación
#
# $$
# \rho_1 g \chi - \rho_1 \partial_t \phi_1 = \rho_2 g \chi - \rho_2 \partial_t \phi_2
# $$
# $$$$
# $$
# \Rightarrow  \rho_1 g \chi_0 + \frac{\rho_1 w^2 \chi_0}{k} coth(k.h_1) = \rho_2 g \chi_0 - \frac{\rho_2 w^2 \chi_0}{k} coth(k.h_2)
# $$
# $$$$
# $$
# \Rightarrow w^2 = \frac{gk(\rho_2 - \rho_1)}{\rho_1 coth(k.h_1) + \rho_2 coth(k.h_2)}
# $$
# $$$$
#
# Obs.: Si $\rho_2 < \rho_1, \Rightarrow w^2<0$ y obtendríamos una frecuencia imaginaria, lo cual resultaría en cosenos no hiperbólicos.
#
# $$$$
# $$$$
# (c)
#
# Partimos de la relación de dispersión
# $$\omega^2=
# \frac{gk(\rho_2-\rho_1)}
# {\rho_1\coth(kh_1)+\rho_2\coth(kh_2)}.
# $$
#
# En el límite $kh_1\to\infty$,
#
# $$
# \coth(kh_1)\longrightarrow 1,
# $$
# por lo que
#
#
# $$\omega^2=
# gk(\rho_2-\rho_1)
# \frac{1}{\rho_1+\rho_2\coth(kh_2)}.
# $$
#
# Como además $kh_2\ll1$, expandimos
#
#
# $$\coth(x)=\frac{1}{x}+\frac{x}{3}-\frac{x^3}{45}
# +\mathcal{O}(x^5)$$
#
# obteniendo
#
#
# $$\omega^2
# \simeq
# gk(\rho_2-\rho_1)
# \frac{1}
# {\rho_1+\rho_2
# \left(
# \frac{1}{kh_2}
# +\frac{kh_2}{3}
# -\frac{(kh_2)^3}{45}
# \right)}$$
#
# Multiplicando numerador y denominador por \(kh_2\),
#
#
# $$\omega^2
# \simeq
# \frac{gh_2(\rho_2-\rho_1)k^2}
# {\rho_2
# \left[
# 1+\frac{\rho_1}{\rho_2}kh_2
# +\frac{(kh_2)^2}{3}
# +\mathcal{O}(k^4)
# \right]}.$$
#
# Tomando la raíz,
#
# $$\omega
# \simeq
# k
# \sqrt{
# \frac{gh_2(\rho_2-\rho_1)}{\rho_2}
# }
# \left(
# 1+\frac{\rho_1}{\rho_2}kh_2
# +\frac{(kh_2)^2}{3}
# \right)^{-1/2}.$$
#
#
# Expandiendo la raíz al primer orden,
#
# $$(1+x)^{-1/2}
# =
# 1-\frac{x}{2}
# +\mathcal{O}(x^2),$$
#
# con
#
# $$x=
# \frac{\rho_1}{\rho_2}kh_2
# +\frac{(kh_2)^2}{3},$$
#
# y descartando términos de orden superior, resulta
#
# $$\omega
# \simeq
# k
# \sqrt{
# \frac{gh_2(\rho_2-\rho_1)}{\rho_2}
# }
# \left(
# 1-
# \frac{\rho_1}{2\rho_2}kh_2
# \right)
# +\mathcal{O}(k^3).$$
#
# Finalmente,
#
# $$\boxed{
# \omega
# \simeq
# k
# \sqrt{
# \frac{gh_2(\rho_2-\rho_1)}{\rho_2}
# }
# -
# \frac{\rho_1h_2}{2\rho_2}
# \sqrt{
# \frac{gh_2(\rho_2-\rho_1)}{\rho_2}
# }
# \,k^2
# +\mathcal{O}(k^3).
# }$$

# %% [markdown]
# (d)
#
# Suponiendo una interacción resonante de tres ondas,
#
# $$
# k_1 = k_2 + k_3,
# \qquad
# \omega_1 = \omega_2 + \omega_3.
# $$
#
# Definimos
#
# $$
# \alpha=\sqrt{\frac{gh_2(\rho_2-\rho_1)}{\rho_2}},
# \qquad
# \alpha\in\mathbb{R},
# \qquad
# \alpha>0,
# $$
#
# y
#
# $$
# \beta=\frac{\rho_1h_2}{2\rho_2}\,\alpha,
# \qquad
# \beta\in\mathbb{R},
# \qquad
# \beta>0.
# $$
#
# La relación de dispersión obtenida en el inciso anterior puede escribirse como
#
# $$\omega=\alpha k-\beta k^2.$$
#
# Entonces,
#
# $$\omega_1
# =
# \alpha k_1-\beta k_1^2
# =
#  \alpha k_2+\alpha k_3
# -\beta k_2^2
# -\beta k_3^2
# -2\beta k_2k_3 = \omega_2 + \omega_3 ,$$
#
# y a la vez
#
# $$\omega_1 = \omega_2 + \omega_3
# =
# \alpha(k_2+k_3)-\beta(k_2+k_3)^2$$
#
# Igualando ambas expresiones,
#
# $$
# \alpha(k_2+k_3)
# -\beta(k_2^2+k_3^2)
# =
# \alpha(k_2+k_3)
# -\beta(k_2^2+k_3^2)
# -2\beta k_2k_3,
# $$
#
# $$
# \Longrightarrow 0=-2\beta k_2k_3.
# $$
#
# Como $\beta>0$, esto sólo puede cumplirse si
#
# $$
# k_2=0
# \quad\text{o}\quad
# k_3=0.
# $$
#
# Por lo que no existe una interacción resonante no trivial de tres ondas.

# %% [markdown]
# ### **Ejercicio 2: Formalismo Hamiltoniano**
#
# En base al análisis anterior, vamos a plantear una Hamiltoniano de interacción a 4 ondas dado por
#  $$ \mathcal{H} = \int \omega_k |a_k|^2~\text{d}k + \int g ~a_k^* a_1^* a_2 a_3 ~\delta(k + k_1 - k_2 - k_3)~\text{d}k_1\text{d}k_2\text{d}k_3\text{d}k $$
# donde $g$ es una amplitud de _scattering_ constante, $a$ es la amplitud compleja asociada y $w_k$ la relación de dispersión del ejercicio anterior.
# Recuerde que puede deshacerse del término lineal en $k$ de $\omega_k$ mediante una transformación de Galileo, por lo que será $\omega_k\propto k^2$.
#
# (a) Usando las ecuaciones de Hamilton, encuentre la ecuación diferencial para $\dot{a}_k$.
#
# (b) Muestre que la ecuación diferencial en derivadas parciales asociada a este Hamiltoniano es
# $$i\frac{∂a}{∂t} = -α\nabla^2a + g|a|²a$$
# para un $α>0$ dependiente de $ω_k$.
# ¿Puede esta ecuación representar un campo escalar real?
#
# (c) Muestre que $E = \int |a(x,t)|^2 \text{d} x$ es una magnitud conservada. ¿Que tipos de dominios y/o condiciones de contorno la vuelven constante?
#
# (d) Plantee una solución tipo onda viajera $a(x,t) = \phi(x-vt) \exp(i\xi)$ para $\xi = \kappa x - \Omega t$ y encuentre los solitones del problema. Considere por separado los casos $g<0$ (solitones brillantes) y $g>0$ (solitones oscuros). Grafique los $\phi(\xi)$ hallados. ¿Por qué se los llama así?
# Muestre que un $\phi$ constante también es solución, por lo que una onda monocromática se mantiene monocromática.
#  _Ayuda: Una ecuación compleja equivale a dos reales, por lo que además podrá determinar el valor de $v$ y $\Omega$ en función de $\kappa$ y la amplitud de $\phi$_.

# %% [markdown]
# **SUS CUENTAS AQUI**

# %% [markdown]
# Como podemos deshacernos del término lineal en $\omega (k)$mediante una transformación de Galileo, utilizamos como relación de dispersión a la expresión $$ \omega (k) = -\alpha k^2, \quad \alpha = \frac{\rho_1 h_2}{2 \rho_2} \sqrt{\frac{g h_2(\rho_2 - \rho_1)}{\rho_2}}, \quad \beta \in \mathbb{R} \quad \beta >0 $$
#
# (a)
#
# $$
# i\dot{a}_k
# =
# \frac{\delta H}{\delta a_k^{*}}
# =
# \omega_k a_k
# +
# g
# \int
# a_1^{*}a_2a_3\,
# \delta(k+k_1-k_2-k_3)\,
# dk_1\,dk_2\,dk_3.
# $$
#
# donde $ \omega_k = -\alpha k^2 $.

# %% [markdown]
# (b)
#
# Partiendo de la ecuación obtenida en el inciso (a),
#
# $$
# i\dot{a}_k
# =
# \omega_k a_k
# +
# g
# \int
# a_1^{*}a_2a_3\,
# \delta(k+k_1-k_2-k_3)\,
# dk_1\,dk_2\,dk_3,
# $$
#
# y tomando
#
# $$
# \omega_k=-\alpha k^2,
# $$
#
# multiplicamos ambos miembros por
#
# $$
# \frac{e^{ikx}}{\sqrt{2\pi}}
# $$
#
# e integramos respecto de \(k\), es decir, aplicamos la transformada inversa de Fourier. De esta forma,
#
# $$
# \int
# i\dot{a}_k
# \frac{e^{ikx}}{\sqrt{2\pi}}
# \,dk
# =
# -\alpha
# \int
# k^2a_k
# \frac{e^{ikx}}{\sqrt{2\pi}}
# \,dk
# +
# g
# \int
# \frac{e^{ikx}}{\sqrt{2\pi}}
# a_1^{*}a_2a_3
# \delta(k+k_1-k_2-k_3)
# \,dk\,dk_1\,dk_2\,dk_3.
# $$
#
# Utilizando las propiedades de la transformada de Fourier,
#
# $$
# \int
# i\dot{a}_k
# \frac{e^{ikx}}{\sqrt{2\pi}}
# \,dk
# =
# i\frac{\partial a}{\partial t},
# $$
#
# y
#
# $$
# -\alpha
# \int
# k^2a_k
# \frac{e^{ikx}}{\sqrt{2\pi}}
# \,dk
# =
# \alpha
# \frac{\partial^2a}{\partial x^2}.
# $$
#
# Además, la función delta permite realizar la integral en \(k\), obteniéndose
#
# $$
# g
# \int
# e^{-ik_1x}
# e^{ik_2x}
# e^{ik_3x}
# a_1^{*}a_2a_3\,
# dk_1\,dk_2\,dk_3
# =
# g\,a^{*}(x,t)a(x,t)a(x,t)
# =
# g|a(x,t)|^2a(x,t).
# $$
#
# Finalmente,
#
# $$
# \boxed{
# i\frac{\partial a}{\partial t}
# =
# \alpha\frac{\partial^2a}{\partial x^2}
# +
# g|a|^2a.
# }
# $$

# %% [markdown]
# (c)
#
# Sea
#
# $$
# E=\int |a(x,t)|^2\,dx.
# $$
#
# Queremos demostrar que
#
# $$
# \frac{dE}{dt}=0.
# $$
#
# Derivando respecto del tiempo,
#
# $$
# \frac{dE}{dt}
# =
# \int
# \frac{\partial}{\partial t}(aa^*)\,dx
# =
# \int
# \left(
# a\dot a^*
# +
# a^*\dot a
# \right)dx.
# $$
#
# De la ecuación obtenida en el inciso anterior,
#
# $$
# i\frac{\partial a}{\partial t}
# =
# -\alpha\nabla^2a
# +
# g|a|^2a,
# $$
#
# se obtiene
#
# $$
# \dot a
# =
# -i\left(-\alpha\nabla^2a+g|a|^2a\right),
# $$
#
# y tomando conjugado complejo,
#
# $$
# \dot a^*
# =
# i\left(-\alpha\nabla^2a^*+g|a|^2a^*\right).
# $$
#
# Sustituyendo,
#
# $$
# \begin{aligned}
# \dot a\,a^*+a\,\dot a^*
# &=
# -i\left(-\alpha\nabla^2a+g|a|^2a\right)a^*
# +i\,a\left(-\alpha\nabla^2a^*+g|a|^2a^*\right) \\
# &=
# i\alpha\left(a^*\nabla^2a-a\nabla^2a^*\right),
# \end{aligned}
# $$
#
# ya que los términos sin derivadas se cancelan
#
# Por lo tanto,
#
# $$
# \frac{dE}{dt}
# =
# i\alpha
# \left(
# \int a^*\nabla^2a\,dx
# -
# \int a\nabla^2a^*\,dx
# \right).
# $$
#
# Integramos por partes cada una de las integrales,
#
# $$
# \int a^*\nabla^2a\,dx
# =
# \left[a^*\nabla a\right]_{borde}
# -
# \int(\nabla a^*)(\nabla a)\,dx,
# $$
#
# y
#
# $$
# \int a\nabla^2a^*\,dx
# =
# \left[a\nabla a^*\right]_{borde}
# -
# \int(\nabla a)(\nabla a^*)\,dx.
# $$
#
# Los términos con integrales se cancelan, obteniéndose
#
# $$
# \boxed{
# \frac{dE}{dt}
# =
# i\alpha
# \left[
# a^*\nabla a
# -
# a\nabla a^*
# \right]_{borde}.
# }
# $$
#
# Luego,
#
# $$
# \frac{dE}{dt}=0
# $$
#
# si se cumplen condiciones de borde tales que
#
# $$
# a=0
# \quad\text{en el borde},
# $$
#
# o bien
#
# $$
# \nabla a=0
# \quad\text{en el borde},
# $$
#
# o en cualquier estado donde
#
# $$
# \left[
# a^*\nabla a \right]_{borde}
# =
# \left[a\nabla a^*
# \right]_{borde}
# $$
#
# $$
# \boxed{
# E=\int|a(x,t)|^2\,dx
# }
# $$
#
# es una cantidad conservada.

# %% [markdown]
# ## (d) Soluciones tipo onda viajera
#
# Planteamos la solución
#
# $$
# a(x,t)=\phi(\xi)e^{i(kx-\Omega t)},
# \qquad
# \xi=x-vt,
# $$
#
# y la reemplazamos en
#
# $$
# i\frac{\partial a}{\partial t}
# =
# -\alpha\nabla^2a
# +
# g|a|^2a.
# $$
#
# Calculamos las derivadas:
#
# $$
# \frac{\partial a}{\partial t}
# =
# -v\frac{\partial\phi}{\partial\xi}e^{i(kx-\Omega t)}
# -i\Omega\phi e^{i(kx-\Omega t)},
# $$
#
# y
#
# $$
# \frac{\partial^2a}{\partial x^2}
# =
# \frac{\partial^2\phi}{\partial\xi^2}e^{i(kx-\Omega t)}
# +
# 2ik\frac{\partial\phi}{\partial\xi}e^{i(kx-\Omega t)}
# -
# k^2\phi e^{i(kx-\Omega t)}.
# $$
#
# Además,
#
# $$
# |a|^2=\phi^2.
# $$
#
# Reemplazando en la ecuación de Schrödinger no lineal y simplificando el factor
# $e^{i(kx-\Omega t)}$, obtenemos
#
# $$
# -i v\frac{\partial\phi}{\partial\xi}
# +\Omega\phi
# =
# -\alpha\left(
# \frac{\partial^2\phi}{\partial\xi^2}
# +
# 2ik\frac{\partial\phi}{\partial\xi}
# -
# k^2\phi
# \right)
# +
# g\phi^3.
# $$
#
# Separando parte real e imaginaria,
#
# $$
# -v\frac{\partial\phi}{\partial\xi}
# =
# -2\alpha k
# \frac{\partial\phi}{\partial\xi},
# $$
#
# y
#
# $$
# \Omega\phi
# =
# -\alpha\frac{\partial^2\phi}{\partial\xi^2}
# +\alpha k^2\phi
# +
# g\phi^3.
# $$
#
# Como buscamos soluciones no constantes,
#
# $$
# v=2\alpha k,
# $$
#
# y la ecuación para $\phi$ queda
#
# $$
# -\alpha\phi''
# +
# (\alpha k^2-\Omega)\phi
# +
# g\phi^3
# =
# 0,
# $$
#
# donde ahora la derivada es respecto de $\xi$.
#
# Multiplicando por $\phi'$,
#
# $$
# -\alpha\phi'\phi''
# +
# (\alpha k^2-\Omega)\phi\phi'
# +
# g\phi^3\phi'
# =
# 0.
# $$
#
# Usando las identidades
#
# $$
# \phi'\phi''
# =
# \frac12\frac{d}{d\xi}(\phi')^2,
# $$
#
# $$
# \phi\phi'
# =
# \frac12\frac{d}{d\xi}(\phi^2),
# $$
#
# $$
# \phi^3\phi'
# =
# \frac14\frac{d}{d\xi}(\phi^4),
# $$
#
# se obtiene
#
# $$
# \frac{d}{d\xi}
# \left[
# -\frac{\alpha}{2}(\phi')^2
# +
# \frac{\alpha k^2-\Omega}{2}\phi^2
# +
# \frac{g}{4}\phi^4
# \right]
# =0,
# $$
#
# e integrando,
#
# $$
# -\frac{\alpha}{2}(\phi')^2
# +
# \frac{\alpha k^2-\Omega}{2}\phi^2
# +
# \frac{g}{4}\phi^4
# =
# C.
# $$
#
# ## Solitón brillante ($g<0$)
#
# Las condiciones de borde son
#
# $$
# \phi(\pm\infty)=0,
# \qquad
# \phi'(\pm\infty)=0,
# $$
#
# por lo que
#
# $$
# C=0.
# $$
#
# Proponemos
#
# $$
# \phi(\xi)
# =
# A\,\operatorname{sech}\!\left(\frac{\xi}{L}\right).
# $$
#
# Su derivada segunda es
#
# $$
# \phi''
# =
# \frac{1}{L^2}\phi
# -
# \frac{2}{A^2L^2}\phi^3.
# $$
#
# Reemplazando,
#
# $$
# -\frac{\alpha}{L^2}\phi
# +
# \frac{2\alpha}{A^2L^2}\phi^3
# +
# (\alpha k^2-\Omega)\phi
# +
# g\phi^3
# =
# 0.
# $$
#
# Como debe cumplirse para todo $\phi$,
#
# $$
# \boxed{
# \Omega
# =
# \alpha k^2
# -
# \frac{\alpha}{L^2},
# }
# $$
#
# y
#
# $$
# \boxed{
# L
# =
# \sqrt{\frac{2\alpha}{A^2|g|}}.
# }
# $$
#
# ## Solitón oscuro ($g>0$)
#
# Las condiciones de borde son
#
# $$
# \phi(\pm\infty)=A,
# \qquad
# \phi'(\pm\infty)=0,
# $$
#
# de donde
#
# $$
# C
# =
# \frac{A^2}{2}(\alpha k^2-\Omega)
# +
# \frac{gA^4}{4}.
# $$
#
# Proponemos
#
# $$
# \phi(\xi)
# =
# A\,\tanh\!\left(\frac{\xi}{L}\right).
# $$
#
# Como
#
# $$
# \phi''
# =
# -\frac{2}{L^2}\phi
# +
# \frac{2}{A^2L^2}\phi^3,
# $$
#
# resulta
#
# $$
# \frac{2\alpha}{L^2}\phi
# -
# \frac{2\alpha}{A^2L^2}\phi^3
# +
# (\alpha k^2-\Omega)\phi
# +
# g\phi^3
# =
# 0.
# $$
#
# Igualando coeficientes,
#
# $$
# \boxed{
# \Omega
# =
# \alpha k^2
# +
# \frac{2\alpha}{L^2},
# }
# $$
#
# y
#
# $$
# \boxed{
# L
# =
# \sqrt{\frac{2\alpha}{A^2g}}.
# }
# $$

# %% [markdown]
# ## **Parte numérica**
#
# Para pasar a la parte numérica, vamos a considerar un dominio periódico de longitud $2\pi L$, tal que el mínimo vector de onda es $k_\text{min} = 1/L$. Esto nos permite inmediatamente definir análogos adimensionales $x' = x/L$ y $k' = kL$ tales que $0 \leq x < 2\pi$ y $k'$ sea entero.
# En particular, trabajaremos con $N=128$ puntos de grilla, por lo que
# $$k'\in\{-N/2, -N/2+1,.., -1, 0, 1, .., N/2-2, N/2-1\}.$$
# Dada la no linealidad del problema, el máximo $k$ que podremos resolver es $k_\text{max} = N/4 = 32$.
# Además, en este caso discreto, la energía introducida en el ejercicio 2(c) toma la forma
# $$ E(t) = \frac{1}{N}\sum_{j=0}^{N-1} |a(x_j, t)|^2 $$
# donde $x_j = 2\pi j/N$ son los puntos de grilla.
# En ```Python```, puede computarse usando ```numpy.mean``` sobre el módulo cuadrado del arreglo real.
# Analizar la conservación de esta energía en las simulaciones es un buen diagnóstico para verificar la correctitud del código.
#
# A continuación están los incisos y los bloques para sus respuestas, junto con algunas funciones útiles. Le sugerimos seguir el orden y la estructura allí propuestos.

# %% [markdown]
# ### **Ejercicio 3: Planteo del método numérico**
#
# (a) Adimensionalice el tiempo $t'=t/t_0$ eligiendo $t_0$ tal que el único parámetro libre es el que acompaña al término no lineal, que llamaremos $\beta$.
#
# (b) Implemente un integrador numérico pseudoespectral en base Fourier para resolver la ecuación diferencial en derivadas parciales deducida en 2(b). La integración temporal debe hacerse con un método de Euler. Use la función provista para realizar el _dealiasing_. _Ayuda: Lea antes los siguientes ejercicios para poder hacer una implementación juiciosa y fácilmente modificable_.
#
# (c) Tome una condición inicial perfectamente bicromática con $k=1$ y $k=2$ de la misma amplitud e integre únicamente por un paso temporal. ¿Qué modos se encienden? Relacionelos con la regla de selección de la interacción a 4 ondas planteada. Repita este análisis para un segundo paso. ¿En cuantos pasos estima que todos los modos estarán encendidos?

# %% [markdown]
# **SUS CUENTAS AQUI: INCISO (a)**

# %% [markdown]
# (a)
#
# Partimos de la ecuación
#
# $$
# i\frac{\partial a}{\partial t}
# =
# -\alpha\frac{\partial^2a}{\partial x^2}
# +
# g|a|^2a.
# $$
#
# Definimos las variables adimensionales
#
# $$
# x'=\frac{x}{L},
# \qquad
# k'=kL,
# \qquad
# 0\le x<2\pi,
# \qquad
# k'\in\mathbb{Z},
# $$
#
# y
#
# $$
# t'=\frac{t}{t_0}.
# $$
#
# Por la regla de la cadena,
#
# $$
# \frac{\partial}{\partial x}
# =
# \frac{1}{L}\frac{\partial}{\partial x'},
# \qquad
# \frac{\partial}{\partial t}
# =
# \frac{1}{t_0}\frac{\partial}{\partial t'},
# $$
#
# por lo que
#
# $$
# \frac{\partial^2}{\partial x^2}
# =
# \frac{1}{L^2}
# \frac{\partial^2}{\partial x'^2}.
# $$
#
# Reemplazando en la ecuación,
#
# $$
# i\frac{1}{t_0}\frac{\partial a}{\partial t'}
# =
# -\frac{\alpha}{L^2}\frac{\partial^2a}{\partial x'^2}
# +
# g|a|^2a.
# $$
#
# Multiplicando por $t_0$,
#
# $$
# i\frac{\partial a}{\partial t'}
# =
# -\frac{\alpha t_0}{L^2}
# \frac{\partial^2a}{\partial x'^2}
# +
# t_0g|a|^2a.
# $$
#
# Elegimos $t_0$ de forma que
#
# $$
# \frac{\alpha t_0}{L^2}=1,
# $$
#
# es decir,
#
# $$
# t_0=\frac{L^2}{\alpha}.
# $$
#
# Finalmente, definiendo
#
# $$
# \beta=\frac{gL^2}{\alpha},
# $$
#
# la ecuación adimensional queda
#
# $$
# \boxed{
# i\frac{\partial a}{\partial t'}
# =
# -\frac{\partial^2a}{\partial x'^2}
# +
# \beta|a|^2a.
# }
# $$

# %%
import numpy as np

# Función de dealiasing (sin precalcular k)
def dealias(f_fft):
    N = f_fft.size
    k2 = np.fft.fftfreq(N)**2
    f_dealias = f_fft
    f_dealias[k2 > k2.max()/4] = 0
    return f_dealias

################################################################################
############################## SU RESOLUCIÓN AQUÍ ##############################
################################################################################

# Inciso (b)

import matplotlib.pyplot as plt

def euler(a_hat, k, dt, beta):

  # Espacio real, para implementar el metodo pseudo espectral
  a = np.fft.ifft(a_hat)

  nl = a*np.abs(a)**2

  nl_hat = np.fft.fft(nl)

  # Queda hacerle dealiasing y aplicar Euler

  nl_hat = dealias(nl_hat)

  a_hat = a_hat + dt * (-1j * k**2 * a_hat -1j * beta * nl_hat)

  return a_hat


N = 128

x = 2*np.pi*np.arange(N)/N

k = np.fft.fftfreq(N, d=1/N)

beta = -1

dt = 1e-5

tf = 1

Nt = int(tf/dt)

# Elijo una condicion inicial arbitrariamente
a = np.exp(1j*x)

a_hat = np.fft.fft(a)

energia = []

for n in range(Nt):

    a_hat = euler(a_hat, k, dt, beta)

    a = np.fft.ifft(a_hat)

    energia.append(np.mean(np.abs(a)**2))
    if n % 1000 == 0:
        print(n, energia[-1], np.max(np.abs(a_hat)))

plt.plot(np.arange(Nt)*dt, energia)
plt.xlabel("t")
plt.ylabel("E(t)")
plt.grid()
plt.show()
# Out:
# 0 1.0 128.0
# 1000 1.0 128.0
# 2000 1.0 128.0
# 3000 1.0 128.0
# 4000 1.0 128.0
# 5000 1.0 128.0
# 6000 1.0 128.0
# 7000 1.0000000000000002 128.0
# 8000 1.0 128.0
# 9000 0.9999999999999999 128.0
# 10000 1.0 128.0
# 11000 1.0 128.0
# 12000 1.0 128.0
# 13000 1.0 128.0
# 14000 0.9999999999999999 128.0
# 15000 1.0 128.0
# 16000 0.9999999999999999 128.0
# 17000 0.9999999999999999 128.0
# 18000 1.0 128.0
# 19000 1.0 128.0
# 20000 1.0 128.0
# 21000 1.0 128.0
# 22000 1.0 128.0
# 23000 1.0 128.0
# 24000 1.0 128.0
# 25000 1.0000000000000004 128.0
# 26000 1.0000000000000016 128.0
# 27000 1.0000000000000075 128.0
# 28000 1.00000000000004 128.0
# 29000 1.0000000000002107 128.0
# 30000 1.0000000000011122 128.0
# 31000 1.0000000000058822 128.0
# 32000 1.0000000000311422 128.0
# 33000 1.000000000165023 127.99999999999977
# 34000 1.000000000875217 127.99999999999937
# 35000 1.0000000046453046 128.00000000000213
# 36000 1.000000024671281 127.99999999998433
# 37000 1.0000001311142626 128.00000000003558
# 38000 1.0000006971782356 128.00000000013108
# 39000 1.0000037089747504 127.99999999838155
# 40000 1.000019741177451 128.00000000742526
# 41000 1.0001051148350841 127.99999998592634
# 42000 1.000559915192302 127.99999992263069
# 43000 1.0029835406941794 128.0000008875719
# 44000 1.015902647066564 127.99999581322193
# 45000 1.084788071473096 128.00000326949174
# 46000 1.4521771377443256 127.99998751814918
# 47000 3.4120129397566576 196.78730279666618
# 48000 13.86901643002102 454.99269453608923
# 49000 69.67432867236818 1051.9903933797825
# 50000 367.55918639910647 2432.311114119591
# 51000 1958.0634836394784 5623.75606573991
# 52000 nan nan
# 53000 nan nan
# 54000 nan nan
# 55000 nan nan
# 56000 nan nan
# C:\Users\User\AppData\Local\Temp\ipykernel_19352\2541602189.py:64: RuntimeWarning: overflow encountered in square
#   energia.append(np.mean(np.abs(a)**2))
# C:\Users\User\AppData\Local\Temp\ipykernel_19352\2541602189.py:24: RuntimeWarning: overflow encountered in square
#   nl = a*np.abs(a)**2
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\fft\_pocketfft.py:101: RuntimeWarning: invalid value encountered in fft
#   return ufunc(a, fct, axes=[(axis,), (), (axis,)], out=out)
# 57000 nan nan
# 58000 nan nan
# 59000 nan nan
# 60000 nan nan
# 61000 nan nan
# 62000 nan nan
# 63000 nan nan
# 64000 nan nan
# 65000 nan nan
# 66000 nan nan
# 67000 nan nan
# 68000 nan nan
# 69000 nan nan
# 70000 nan nan
# 71000 nan nan
# 72000 nan nan
# 73000 nan nan
# 74000 nan nan
# 75000 nan nan
# 76000 nan nan
# 77000 nan nan
# 78000 nan nan
# 79000 nan nan
# 80000 nan nan
# 81000 nan nan
# 82000 nan nan
# 83000 nan nan
# 84000 nan nan
# 85000 nan nan
# 86000 nan nan
# 87000 nan nan
# 88000 nan nan
# 89000 nan nan
# 90000 nan nan
# 91000 nan nan
# 92000 nan nan
# 93000 nan nan
# 94000 nan nan
# 95000 nan nan
# 96000 nan nan
# 97000 nan nan
# 98000 nan nan
# 99000 nan nan

# %% [markdown]
# Obs.: la energía se mantiene casi constante durante los primeros pasos, pero luego comienza a diverger hasta explotar finalmente alrededor del paso 50.000

# %%
# Inciso (c)

N = 128
dt = 1e-4
beta = 1

k = np.fft.fftfreq(N, d=1/N)

# Condición inicial
a = np.exp(1j*x) + np.exp(2j*x)
a_hat = np.fft.fft(a)


# Un solo paso

a_hat1 = euler(a_hat.copy(), k, dt, beta)

tol = 1e-8

print("Modos encendidos luego de 1 paso:")

for i in np.where(np.abs(a_hat1) > tol)[0]:
    print(f"k = {i:2d}, |a_hat| = {abs(a_hat1[i]):.3e}")
# Out:
# Modos encendidos luego de 1 paso:
# k =  0, |a_hat| = 1.280e-02
# k =  1, |a_hat| = 1.280e+02
# k =  2, |a_hat| = 1.280e+02
# k =  3, |a_hat| = 1.280e-02

# %%
# Luego de dos pasos

a_hat2 = euler(a_hat1.copy(), k, dt, beta)

print("\nModos encendidos luego de 2 pasos:")

for i in np.where(np.abs(a_hat2) > tol)[0]:
    print(f"k = {i:2d}, |a_hat| = {abs(a_hat2[i]):.3e}")
# Out:
# Modos encendidos luego de 2 pasos:
# k =  0, |a_hat| = 2.560e-02
# k =  1, |a_hat| = 1.280e+02
# k =  2, |a_hat| = 1.280e+02
# k =  3, |a_hat| = 2.560e-02
# k =  4, |a_hat| = 1.280e-06
# k = 127, |a_hat| = 1.280e-06

# %% [markdown]
# Para relacionar la cantidad de modos activados hay que tener en cuenta la regla de selección $ \quad k = k_2 + k_3 - k_1 \quad $. Como inicialmente solamente tenemos los modos 1 y 2, los posibles valores para k son 0, 1, 2 y 3; mientras que en el siguiente paso, al ya estar encendidos todos esos modos, los posibles valores para k son -1, 0, 1, 2, 3 y 4.
#
# Veo que al aumentar un paso se encienden dos nuevos modos, el cuarto y el -1 (representado por el 127). Al estar $k$ acotado entre $-32\le k \le 32 $, estimo que en 31 pasos estarán todos los modos encendidos.

# %% [markdown]
# ### **Ejercicio 4: Dinámica de los modos**
#
# (a) Modifique el algoritmo del Ejercicio 3(a) para que realice la integración temporal con un método de Runge-Kutta de orden 4 (RK4). Eligiendo el paso temporal $\Delta t$ apropiado, repita la integración del Ejercicio 3(c) anterior hasta $t=2$ y grafique su evolución para los casos $\beta = -1$ y $\beta = 1$. _Ayuda: Use la funcion de visualización provista para visualizar $a(t,x)$, por ejemplo, mediante su módulo, fase, parte real y/o parte imaginaria._
#
# (b) Considere $\beta = 1$ y tome una condición inicial de ruido blanco $|a_k(t=0)| = \alpha$ para $|k|<k_\text{max}$ y $\alpha$ constante. Integre hasta $t=5$ y analice el espectro espacio-temporal. ¿Se cumple la relación de dispersión hallada en el Ejercicio 1(b)? ¿Que ocurre a medida que varía $\alpha$? _Ayuda: Puede usar la función provista, pero tome logaritmo al espectro para visualizarlo mejor_.
#
# (c) Grafique $\Delta E(t) = E(t) - E(0)$ para verificar que la conservación probada en el Ejercicio 2(c) se cumple aproximadamente en todos los casos. _Ayuda: Puede serle útil graficar $|\Delta E(t)|$ en escala logarítmica_.

# %% [markdown]
# a)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función de dealiasing
def dealias(f_fft):
    N = f_fft.size
    k2 = np.fft.fftfreq(N)**2
    f_dealias = f_fft.copy()
    f_dealias[k2 > k2.max()/4] = 0
    return f_dealias

# Lado derecho de la ecuación
def rhs(a_hat, k, beta):

    # Paso al espacio real
    a = np.fft.ifft(a_hat)

    # Término no lineal
    nl = a * np.abs(a)**2
    nl_hat = np.fft.fft(nl)

    # Dealiasing
    nl_hat = dealias(nl_hat)

    # RHS
    return -1j*k**2*a_hat -1j*beta*nl_hat


# Paso temporal RK4
def rk4(a_hat, k, dt, beta):

    k1 = rhs(a_hat, k, beta)
    k2 = rhs(a_hat + dt*k1/2, k, beta)
    k3 = rhs(a_hat + dt*k2/2, k, beta)
    k4 = rhs(a_hat + dt*k3, k, beta)

    return a_hat + dt*(k1 + 2*k2 + 2*k3 + k4)/6


###########################################################

N = 128

x = 2*np.pi*np.arange(N)/N
k = np.fft.fftfreq(N, d=1/N)

beta = -1

dt = 1e-5
tf = 1
Nt = int(tf/dt)

# Condición inicial
a = np.exp(1j*x)
a_hat = np.fft.fft(a)

energia = []

for n in range(Nt):

    a_hat = rk4(a_hat, k, dt, beta)

    a = np.fft.ifft(a_hat)

    energia.append(np.mean(np.abs(a)**2))

    if n % 1000 == 0:
        print(n, energia[-1], np.max(np.abs(a_hat)))

plt.plot(np.arange(Nt)*dt, energia)
plt.xlabel("t")
plt.ylabel("E(t)")
plt.grid()
plt.show()
# Out:
# 0 1.0 128.0
# 1000 1.0 128.0
# 2000 1.0 128.0
# 3000 1.0 128.0
# 4000 1.0 128.0
# 5000 1.0 128.0
# 6000 1.0 128.0
# 7000 1.0 128.0
# 8000 1.0 128.0
# 9000 1.0 128.0
# 10000 1.0 128.0
# 11000 1.0 128.0
# 12000 1.0 128.0
# 13000 1.0 128.0
# 14000 1.0 128.0
# 15000 1.0 128.0
# 16000 1.0 128.0
# 17000 1.0 128.0
# 18000 1.0 128.0
# 19000 1.0 128.0
# 20000 1.0 128.0
# 21000 1.0 128.0
# 22000 1.0 128.0
# 23000 1.0 128.0
# 24000 1.0 128.0
# 25000 1.0 128.0
# 26000 1.0 128.0
# 27000 1.0 128.0
# 28000 1.0 128.0
# 29000 1.0 128.0
# 30000 1.0 128.0
# 31000 1.0 128.0
# 32000 1.0 128.0
# 33000 1.0 128.0
# 34000 1.0 128.0
# 35000 1.0 128.0
# 36000 1.0 128.0
# 37000 1.0 128.0
# 38000 1.0 128.0
# 39000 1.0 128.0
# 40000 1.0 128.0
# 41000 1.0 128.0
# 42000 1.0 128.0
# 43000 1.0 128.0
# 44000 1.0 128.0
# 45000 1.0 128.0
# 46000 1.0 128.0
# 47000 1.0 128.0
# 48000 1.0 128.0
# 49000 1.0 128.0
# 50000 1.0 128.0
# 51000 1.0 128.0
# 52000 1.0 128.0
# 53000 1.0 128.0
# 54000 1.0 128.0
# 55000 1.0 128.0
# 56000 1.0 128.0
# 57000 1.0 128.0
# 58000 1.0 128.0
# 59000 1.0 128.0
# 60000 1.0 128.0
# 61000 1.0 128.0
# 62000 1.0 128.0
# 63000 1.0 128.0
# 64000 1.0 128.0
# 65000 1.0 128.0
# 66000 1.0 128.0
# 67000 1.0 128.0
# 68000 1.0 128.0
# 69000 1.0 128.0
# 70000 1.0 128.0
# 71000 1.0 128.0
# 72000 1.0 128.0
# 73000 1.0 128.0
# 74000 1.0 128.0
# 75000 1.0 128.0
# 76000 1.0 128.0
# 77000 1.0 128.0
# 78000 1.0 128.0
# 79000 1.0 128.0
# 80000 1.0 128.0
# 81000 1.0 128.0
# 82000 1.0 128.0
# 83000 1.0 128.0
# 84000 1.0 128.0
# 85000 1.0 128.0
# 86000 1.0 128.0
# 87000 1.0 128.0
# 88000 1.0 128.0
# 89000 1.0 128.0
# 90000 1.0 128.0
# 91000 1.0 128.0
# 92000 1.0 128.0
# 93000 1.0 128.0
# 94000 1.0 128.0
# 95000 1.0 128.0
# 96000 1.0 128.0
# 97000 1.0 128.0
# 98000 1.0 128.0
# 99000 1.0 128.0

# %%
import numpy as np

def espectro_espaciotemporal(f, dx, dt):
  """
  Calcula el espectro espacio-temporal de una función f(t, x).

  Args:
    f (np.ndarray): Array 2D de la función f(x,t) con dimensiones (Nt, Nx).
    dx (float): Paso espacial.
    dt (float): Paso temporal.

  Returns:
    w (np.ndarray): Frecuencias temporales.
    k (np.ndarray): Números de onda espaciales.
    spec (np.ndarray): Espectro de Fourier 2D de f(x,t)
  """
  Nt, Nx = f.shape
  ns = np.arange(Nt)/Nt
  new_f = np.sin(np.pi*ns)[:, None]*f    # Ventana de Hann en el tiempo
  w = 2*np.pi*np.fft.fftfreq(Nt, dt)
  k = 2*np.pi*np.fft.fftfreq(Nx, dx)
  spec = np.abs(np.fft.fft2(new_f))**2 # Espectro 2D
  return w[w>0], k[k>0], spec[w>0, k>0]  # Devuelvo solo los valores positivos

################################################################################
############################## SU RESOLUCIÓN AQUÍ ##############################
################################################################################

# %% [markdown]
# ### **Ejercicio 5: Dinámica de solitones**
#
# En esta sección, nos concentraremos en los solitones brillantes hallados en el Ejercicio 2(d), por lo que tomaremos $\beta = -1$.
#
# (a) Tome cómo condición inicial el solitón hallado en el Ejercicio 1(d) centrado en $x=\pi$ y grafique su evolución a tiempo largo para distintas velocidades de propagación $\Omega/\kappa = 0.25, 1, 4$, ¿se mantiene estable? Grafique $|\Delta E(t)| = |E(t) - E(0)|$ para verificar la conservación probada en el Ejercicio 2(c). Repita este análisis bajando $\Delta t$ a la mitad, ¿que cambios observa? _Ayuda: Puede serle útil graficar $|\Delta E(t)|$ en escala logarítmica_.
#
# (b) Introduzca dos solitones en $x=\pi/2$ y $x=3\pi/2$ con velocidad de propagación positiva y negativa, respectivamente, a modo de generar un encuentro. Grafique su evolución temporal a lo largo de un puñado de encuentros y monitoree $|\Delta E(t)|$. ¿Son interactuantes?
#
# (c) Grafique el espectro espacial antes, durante y después del choque. Comparelos con el espectro espacial de un único solitón, ¿que diferencias observa? _Aclaración: Note que dado que la evolución de un único solitón es una traslación rígida, su espectro de energía no cambiará. Esto se debe a que un desplazamiento $\Delta x$ en espacio real equivale a multiplicar por un fasor $e^{ik\Delta x}$ en espacio Fourier_.

# %%
# SU RESOLUCIÓN AQUÍ

# %% [markdown]
# ## **Funcion auxiliar para animar la curva**
#
# Esta es una función para animar múltiples curvas $f_1(t,x),\dots, f_n(t,x)$ y su evolución temporal

# %%
# FUNCION PARA ANIMAR
def grafico1d_animado(abscisas, ordenadas, dt, leyendas=None, titulo="",
                      etiqueta_x="", etiqueta_y="", paso=1, rescalar=False):
    """
    Genera un gráfico animado 1D de multiples funciones f1(t,x),..,fn(t,x)

    Entrada:
        - `abscisas`:   arreglo 1D o lista de arreglos 1D con las abscisas para
                            cada conjunto de datos.
        - `ordenadas`:  arreglo de dimensión 2 con el valor de las ordenadas
                            para cada tiempo. La cantidad de filas corresponde
                            a la cantidad de niveles temporales y debe ser igual
                            para cada conjunto de datos. La cantidad de columnas
                            debe coincidir con la cantidad de elementos en las
                            abscisas.
        - `dt`:         paso temporal entre muestras.
        - `leyendas`:   string o lista de strings con la etiqueta para cada set
                            de datos.
        - `titulo`:     string con el título del gráfico.
        - `etiqueta_x`: string con la etiqueta para el eje x [OPCIONAL].
        - `etiqueta_y`: string con la etiqueta para el eje y [OPCIONAL].
        - `paso`:       espaciamiento en los datos para cada fotograma.
        - `rescalar`:   True para recalcular los limites de la figura en cada
                            fotograma.

    Salida:
        - `anim`:   referencia al objeto de animación creado.
    """

    import numpy as np
    import matplotlib.pyplot as plt
    import matplotlib.animation as animation

    #   Control de errores y flexibilidad para permitir uno o varios
    # sets de datos.
    if not isinstance(abscisas, list):
        if not isinstance(abscisas, np.ndarray):
            print("El primer argumento de `grafico1d_animado` debe ser un "
                  "arreglo con las abscisas o una lista de arreglos.")
            raise
        else:
            abscisas = [abscisas]

    if (not isinstance(ordenadas, list)):
        if (not isinstance(ordenadas, np.ndarray)):
            print("El segundo argumento de `grafico1d_animado` debe ser un "
                  "arreglo con los datos o una lista de arreglos.")
            raise
        else:
            ordenadas = [ordenadas]

    if len(abscisas) != len(ordenadas):
        print("La cantidad de arreglos de abscisas y de ordenadas debe "
              "ser la misma.")
        raise

    if leyendas and isinstance(leyendas, list):
        if len(ordenadas) != len(leyendas):
            print("Ordenadas y leyendas deben tener la misma cantidad de ",
                  "elementos.")
            raise
    else:
        leyendas = [leyendas]

    # Guardo el estado de plt
    params_viejos = plt.rcParams
    plt.rc('animation', html='jshtml')

    num_foto = ordenadas[0].shape[0]

    fig, ax = plt.subplots(1, 1, figsize=(8,4), constrained_layout=True)
    plt.close();  # Cerrar la figura, animation va a crear la suya propia

    # Inicializo las curvas
    plots = [ ax.plot([], [], label=leyendas[i])[0]
              for i in range(len(ordenadas)) ]
    ax.set_title(titulo + f" $t=0$")
    ax.set_xlabel(etiqueta_x)
    ax.set_ylabel(etiqueta_y)

    def init():
        """ Inicializador de la figura y gráfico de condiciones iniciales."""
        for i, (x, f) in enumerate(zip(abscisas, ordenadas)):
            plots[i].set_xdata(x)
            plots[i].set_ydata(f[0])

        ax.relim()
        ax.autoscale_view()

        return plots

    def actualizar(t):
        """ Actualiza los datos al fotograma actual."""
        print(f"\rCalculando fotograma {t//paso} de {(num_foto-1)//paso}",
              end="")
        for i, f in enumerate(ordenadas):
            plots[i].set_ydata(f[t])

        ax.set_title(titulo + f" $t={t*dt:.5f}$")

        if rescalar:
            ax.relim()
            ax.autoscale_view()

        return plots

    anim = animation.FuncAnimation(fig, actualizar, init_func=init,
                                   frames=range(0, num_foto, paso),
                                   blit=True, repeat=True)

    # Restauro el estado de plt
    plt.rc(params_viejos)

    return anim
